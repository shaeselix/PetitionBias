# %%
from selenium import webdriver
from urllib.parse import urlencode
import requests
from bs4 import BeautifulSoup
import re
import numpy as np
from nltk.classify import naivebayes

# %%
# %run ChangeScraper.py

# %%
t = ChangeScraper()

# %%
t.Search('Israel')
# Out:
# "Israel": 372 results
# Continue? (y/n): y
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-159-61a6731eb7b5> in <module>()
# ----> 1 t.Search('Israel')
#
# /Users/shaeselix/Documents/Python/Change/ChangeScraper.py in Search(self, query, auto)
#      47             for e in results:
#      48
# ---> 49                 self.df.loc[self.dflen] = self.Parse(e.get_attribute('href'))
#      50                 self.dflen += 1
#      51                 if self.dflen % 100 == 0:
#
# /Users/shaeselix/Documents/Python/Change/ChangeScraper.py in Parse(self, link)
#      74         description = soup.find('div', 'rte js-description-content').get_text(' ')
#      75
# ---> 76         petitioning = soup.find('span', 'link-stealth link').string
#      77
#      78         lsoup = soup.find('div', "modal-dialog animate animate-zoom-in modal-medium")
#
# ...

# %%
t.df.to_csv('first60petitions.csv')

# %%
t.driver.close()
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-117-bae750a01d52> in <module>()
# ----> 1 t.driver.close()
#
# //anaconda/lib/python3.4/site-packages/selenium/webdriver/remote/webdriver.py in close(self)
#     471             driver.close()
#     472         """
# --> 473         self.execute(Command.CLOSE)
#     474
#     475     def quit(self):
#
# //anaconda/lib/python3.4/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     199         response = self.command_executor.execute(driver_command, params)
#     200         if response:
# --> 201             self.error_handler.check_response(response)
#     202             response['value'] = self._unwrap_value(
#     203                 response.get('value', None))
#
# ...

# %%
test = requests.get('https://www.change.org/p/bbc-trust-organise-debate-on-israel-palestine-coverage')

# %%
test2 = requests.get('https://www.change.org/p/house-of-reps-protect-israel-from-the-bad-iran-nuclear-deal')
soup2 = BeautifulSoup(test2.text, 'html.parser')

# %%
soup = BeautifulSoup(test.text, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE doctype html>
# <html lang="en-US">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="en-US" http-equiv="Content-Language"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="@change" name="twitter:site"/>
#   <meta content="@change" name="twitter:creator"/>
#   <meta content="Change.org" property="og:site_name"/>
#   <meta content="48409868550" property="fb:app_id"/>
#   <meta content="BBC Trust: Organise debate on Israel-Palestine coverage" property="og:title"/>
#   <meta content="" property="og:description"/>
#   <meta content="en_US" property="og:locale"/>
#   <meta content="http://d22r54gnmuhwmk.cloudfront.net/photos/7/fm/sk/rqfMSKRjvwVxfST-1600x900-noPad.jpg?1423798793" property="og:image"/>
#   <meta content="https://www.change.org/p/bbc-trust-organise-debate-on-israel-palestine-coverage" property="og:url"/>
#   <meta content="change-org:petition" property="og:type"/>
#   <meta content="summary" name="twitter:card"/>
# ...

# %%
re.search('[0-9]+',str(soup.find("div", "emergency_banner"))).group(0)
# Out:
# '3930432'

# %%
letter = soup.find('div', "modal-dialog animate animate-zoom-in modal-medium")
letter.find('p').get_text(' ')
# Out:
# 'I do not support the Iran nuclear deal -- and I strongly urge you to vote to reject it. Iran has violated over 20 international agreements. And it’s the leading state sponsor of terrorism. How can we trust Iran with this nuclear deal? Please vote to reject a bad nuclear deal with Iran. We need a better deal.'

# %%
sigtext = soup.find('div', 'js-sign-and-share-components').find('div', 'type-weak type-xs').get_text()
sigtext
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-140-09c553d31a70> in <module>()
# ----> 1 sigtext = soup.find('div', 'js-sign-and-share-components').find('div', 'type-weak type-xs').get_text()
#       2 sigtext
#
# AttributeError: 'NoneType' object has no attribute 'get_text'

# %%
v = soup.find('div', 'js-sign-and-share-components').get_text()

# %%
nv = soup2.find('div', 'js-sign-and-share-components').get_text()

# %%
v[0:7]
# Out:
# 'Victory'

# %%
int(re.search('[0-9,]+',nv).group(0).replace(',',''))
# Out:
# 59350

# %%
import pandas as pd

# %%
df = pd.read_csv('first60petitions.csv')

# %%
df['Category'] = 0

# %%
df.head()
# Out:
#    Unnamed: 0       ID                                               Link  \
# 0           0  3405145  https://www.change.org/p/caetano-veloso-gilber...
# 1           1  3967540  https://www.change.org/p/house-of-reps-protect...
# 2           2  3659279  https://www.change.org/p/bon-jovi-bon-jovi-boy...
# 3           3  1475699  https://www.change.org/p/uk-supermarkets-boyco...
# 4           4  3711487  https://www.change.org/p/war-on-want-israel-pa...
#
#                                                Title  \
# 0  Cancelem vosso show em Israel   Cancel your co...
# 1      Protect Israel from the bad Iran nuclear deal
# 2                           Bon Jovi, Boycott Israel
# 3          Boycott Israel & Illegal Settlement Goods
# 4           STOP ISRAEL KILLING PALESTINIAN CHILDREN
#
#                                              Sponsor  \
# 0               Tropicália não combina com apartheid
# 1                   Citizens for a Nuclear Free Iran
# ...

# %%
for i in range(31):
    row = df.loc[i]
    print(row.Title)
    print(row.Description)
    cat = input('Category: ')
    df.loc[i, 'Category'] = int(cat)
# Out:
# Cancelem vosso show em Israel   Cancel your concert in Israel
# (English below) Queridos Caetano e Gil,
#  Com admiração ao trabalho de vocês e seu histórico de comprometimento com lutas pela liberdade, justiça e igualdade, pedimos que cancelem vosso show em Israel, previsto para 28 de julho. A data coincide com o aniversário de um ano dos ataques de Israel a Gaza, nos quais mais de 2 mil palestinas e palestinos foram mortos, incluindo mais 500 crianças. Ainda hoje, mais de 100 mil pessoas seguem desabrigadas em decorrência da ofensiva.
# ...

# %%
for i in range(31,40):
    row = df.loc[i]
    print(row.Title)
    print(row.Description)
    cat = input('Category: ')
    df.loc[i, 'Category'] = int(cat)
# Out:
# End all Live Exports to Israel בטל את המשלוחים החיים לישראל!
# המשלוחים החיים: התאכזרות לבעלי חיים, פגיעה סביבתית וסכנה בריאותית!
#  מאות אלפי עגלים וטלאים מובאים לישראל מדי שנה באוניות ובמטוסים מאוסטרליה ומאירופה למטרת פיטום, שחיטה ושיווק כבשר טרי. הם מגיעים במסע ארוך ומייסר בים, שבמהלכו הם כלואים בצפיפות, מתבוססים בצואתם ובצואת חבריהם וסובלים מחום כבד, מרעש ומטלטלות האונייה. מסע הייסורים עלול להימשךשבועות ארוכים, ורבים אינם מצליחים לשרוד עד סופו. המתים בדרך מושלכים לים, ואלה ששרדו נפרקים מהאונייה באלימות רבה - במכות, דחיפות, בעיטות וחשמול. הם מועברים להסגרים, משם למכלאות פיטום, ולבסוף לשחיטה.
#  המשלוחים החיים מזיקים גם לסביבה. לא זו בלבד שהם חלק מתעשיית הבשר, שנמצאה גורם ראשי לזיהום אוויר, מקורות מים וקרקע ולפגיעה במגוון המינים הביולוגי, המשלוחים החיים גם מזהמים את הים ופוגעים במערכת האקולוגית הימית בשל כמויות עצומות של הפרשות וכן גוויות בעלי חיים הנזרקות לים. לעתים תכופות הגוויות נסחפות אל החופים, וכבר הגיעו לא אחת לחופי ישראל.
# ...

# %%
df2 = pd.read_csv('first60petitions_categories.csv')

# %%
df.loc[34:,'Category'] = df2.loc[34:,'Category']

# %%
# Out:
# 0     1
# 1     0
# 2     1
# 3     1
# 4     1
# 5     1
# 6     1
# 7     0
# 8     0
# 9     2
# 10    0
# 11    1
# 12    0
# 13    1
# 14    2
# 15    0
# 16    0
# 17    1
# 18    2
# 19    2
# 20    1
# 21    2
# 22    2
# 23    1
# 24    2
# 25    2
# 26    2
# 27    1
# 28    2
# 29    2
#      ..
# 31    2
# 32    2
# 33    2
# 34    1
# 35    0
# 36    1
# 37    2
# 38    2
# 39    1
# 40    1
# 41    2
# 42    1
# 43    0
# 44    2
# 45    1
# 46    0
# 47    2
# 48    1
# 49    1
# 50    1
# 51    0
# 52    2
# 53    1
# 54    1
# 55    1
# 56    2
# 57    2
# 58    1
# 59    2
# 60    2
# Name: Category, dtype: int64

# %%
nb = naivebayes.NaiveBayesClassifier()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-193-69bb260d941e> in <module>()
# ----> 1 nb = naivebayes.NaiveBayesClassifier()
#
# TypeError: __init__() missing 2 required positional arguments: 'label_probdist' and 'feature_probdist'

# %%
train = df.loc[:46]

# %%
from nltk import word_tokenize# or use some other tokenizer

# %%
descriptionlist = list(train.Description)
all_words = set(word.lower() for passage in descriptionlist for word in word_tokenize(passage))
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# <ipython-input-197-613a7822ad36> in <module>()
#       1 descriptionlist = list(train.Description)
# ----> 2 all_words = set(word.lower() for passage in descriptionlist for word in word_tokenize(passage))
#
# <ipython-input-197-613a7822ad36> in <genexpr>(.0)
#       1 descriptionlist = list(train.Description)
# ----> 2 all_words = set(word.lower() for passage in descriptionlist for word in word_tokenize(passage))
#
# //anaconda/lib/python3.4/site-packages/nltk/tokenize/__init__.py in word_tokenize(text, language)
#     102     :param language: the model name in the Punkt corpus
#     103     """
# --> 104     return [token for sent in sent_tokenize(text, language)
#     105             for token in _treebank_word_tokenize(sent)]
#     106
#
# ...

# %%
tokens = word_tokenize('Hello my name')
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# <ipython-input-210-436f39ec7b7c> in <module>()
# ----> 1 tokens = word_tokenize('Hello my name')
#
# //anaconda/lib/python3.4/site-packages/nltk/tokenize/__init__.py in word_tokenize(text, language)
#     102     :param language: the model name in the Punkt corpus
#     103     """
# --> 104     return [token for sent in sent_tokenize(text, language)
#     105             for token in _treebank_word_tokenize(sent)]
#     106
#
# //anaconda/lib/python3.4/site-packages/nltk/tokenize/__init__.py in sent_tokenize(text, language)
#      86     :param language: the model name in the Punkt corpus
#      87     """
# ---> 88     tokenizer = load('tokenizers/punkt/{0}.pickle'.format(language))
#      89     return tokenizer.tokenize(text)
#      90
#
# ...

# %%
descriptionlist[0]
# Out:
# '(English below) Queridos Caetano e Gil, \n Com admiração ao trabalho de vocês e seu histórico de comprometimento com lutas pela liberdade, justiça e igualdade, pedimos que cancelem vosso show em Israel, previsto para 28 de julho. A data coincide com o aniversário de um ano dos ataques de Israel a Gaza, nos quais mais de 2 mil palestinas e palestinos foram mortos, incluindo mais 500 crianças. Ainda hoje, mais de 100 mil pessoas seguem desabrigadas em decorrência da ofensiva. \n Tocar em Israel é endossar políticas e práticas racistas, coloniais e de apartheid -ilegais sob o direito internacional. Ademais, o governo israelense apresenta os shows em Israel como um sinal de aprovação a suas políticas. Israel viola sistematicamente o direito internacional ao impedir o retorno dos refugiados palestinos, ao colonizar e ocupar a Cisjordânia e a Faixa de Gaza e ao discriminar sistematicamente os palestinos cidadãos de Israel. As políticas discriminatórias de Israel também se manifestam contr
# ...
